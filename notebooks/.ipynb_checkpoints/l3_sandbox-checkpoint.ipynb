# %% [markdown]
# This notebook walks through the group level analyses for Developmental differences in learning from large losses study. Details of the behavioral analyses can be found [here](https://zenkavi.github.io/DevStudy_Analyses/output/reports/DevStudy_MG_Behavior.nb.html).
#
# Import packages

# %%
import glob
import nibabel as nib
from nilearn.image import concat_imgs
import numpy as np
import os
import pandas as pd
import re
import sys
sys.path.append(os.environ['SERVER_SCRIPTS'])
from utils.mni2vox import mni2vox
import warnings

# %% [markdown]
# Load plotting packages

# %%
from matplotlib.colors import ListedColormap
import matplotlib.patheffects as PathEffects
import matplotlib.pyplot as plt
from scipy.stats import norm
import seaborn as sns
from nistats.reporting import plot_design_matrix, plot_contrast_matrix, get_clusters_table
from nilearn import plotting, image
from atlasreader import create_output

# %matplotlib inline
# Out:
# The Python package you are importing, AtlasReader, is licensed under the
# BSD-3 license; however, the atlases it uses are separately licensed under more
# restrictive frameworks.
# By using AtlasReader, you agree to abide by the license terms of the
# individual atlases. Information on these terms can be found online at:
# https://github.com/miykael/atlasreader/tree/master/atlasreader/data

# %% [markdown]
# Helper function to order plots

# %%
def get_index(elem):
    if(os.path.basename(elem).split("_")[2] == "neg"):
        key_name = os.path.basename(elem).split("_")[3]
    else:
        key_name = os.path.basename(elem).split("_")[2]
    myorder = {"m1":0, "m2":1, "m3":2, "m4":3, "task":4, "rt":5, "hpe":6, "lpe":7, "pe":8, "ev":9, "var":10}
    return myorder[key_name]

# %%
data_loc = os.environ['DATA_LOC']
#/oak/stanford/groups/russpold/data/ds000054/0.0.4

# %% [markdown]
# # Statistical tests
#
# Level 3 script can be found [here](https://github.com/zenkavi/DevStudy_ServerScripts/blob/master/nistats/level_3/level_3.py)
#
# ## Model 1: Task regressors vs. baseline

# %% [markdown]
# Randomise cluster corrected p values. Presenting all task-related regressors to give a general sense of the dataset.
#
# - Activity during the presentation of all stimuli exhibits a task-positive pattern with decreased activity in a large mPFC cluster and increased activity in frontal pole, inferior frontal gyrus, insula, paracingulate gyrus/supplementary motor cortex, occipital pole.
# - The relationship between BOLD activity and convolved PE regressors separately for high and low variance machines does not survive whole brain correction compared to baseline in any region (worrying given prior literature)
# - For all subjects we find significantly higher activity that survives whole brain correction bilaterally in VStr in response to positive EV machines compared to negative EV machines. In contrast we do not find any difference when comparing the relationship between BOLD and the presentation of high or low variance machines.

# %%
all_paths = glob.glob('%s/derivatives/nistats/level_3/model1/*/*corrp_tstat1*'%(data_loc))
neg_t_corrected_p_paths = [x for x in all_paths if "neg" in x]
pos_t_corrected_p_paths = [x for x in all_paths if "neg" not in x]
neg_t_corrected_p_paths = sorted(neg_t_corrected_p_paths, key=get_index)
pos_t_corrected_p_paths = sorted(pos_t_corrected_p_paths, key=get_index)

for i in range(0, len(pos_t_corrected_p_paths)):
    #determine display coordinates
    if any(x in os.path.basename(pos_t_corrected_p_paths[i]) for x in ['m1', 'm2', 'm3', 'm4', 'task_on']):
        fig = plotting.plot_stat_map(image.smooth_img(neg_t_corrected_p_paths[i],5), colorbar=False, title=os.path.basename(pos_t_corrected_p_paths[i]), threshold=0.95, draw_cross=False)
    else:
        fig = plotting.plot_stat_map(image.smooth_img(pos_t_corrected_p_paths[i],5), colorbar=False, title=os.path.basename(pos_t_corrected_p_paths[i]), threshold=0.95, draw_cross=False)
    fig.add_overlay(image.smooth_img(pos_t_corrected_p_paths[i],5), threshold=0.95, cmap=plotting.cm.black_red, colorbar=True)
    fig.add_overlay(image.smooth_img(neg_t_corrected_p_paths[i],5), threshold=0.95, cmap=plotting.cm.black_blue, colorbar=False)

# %% [markdown]
# Since we have strong apriori expectation on the location of PE regressors we check if there anything that doesn't survive correction?
#
# Not for HPE (first plot) but for LPE (second plot) we do find the expected activity in caudate.

# %%
all_paths = glob.glob('%s/derivatives/nistats/level_3/model1/*pe/*tstat1*'%(data_loc))
all_paths = [x for x in all_paths if "corrp" not in x and "neg" not in x and "png" not in x and "csv" not in x]
all_paths = [x for x in all_paths if len(os.path.basename(x).split("_")[2])>2]
for i in range(0, len(all_paths)):
    fig = plotting.plot_stat_map(all_paths[i], colorbar=True, title=os.path.basename(all_paths[i]), threshold=3, draw_cross=False, cut_coords = [-13,16,-1])

# %%
#create_output(all_paths[1], cluster_extent=5, voxel_thresh = 3)

# %% [markdown]
# The clusters for the LPE regressor that do not survive whole-brain correction are:

# %%
lpe_clusters = pd.read_csv('%s/rand_model1_lpe_tstat1_cluster_clusters.csv'%(os.path.dirname(all_paths[1])))
lpe_clusters
# Out:
#     cluster_id  peak_x     peak_y  peak_z  cluster_mean    volume_mm  \
# 0            1  21.404 -72.100000    34.8       3.48168  117099.0000
# 1            2 -21.724  28.532000    20.4       3.43655    6930.3100
# 2            3  19.008 -81.684000   -42.0       3.42755    6654.7500
# 3            4   2.236  -5.012000    10.8       3.37440    4643.1700
# 4            5  -9.744  62.076000   -15.6       3.37817    4036.9400
# 5            6 -16.932 -84.080000   -42.0       3.53896    2976.0400
# 6            7 -33.704  -0.220005    37.2       3.28211    1832.4700
# 7            8 -40.892  57.284000    10.8       3.23665    1818.6900
# 8            9  52.552  16.552000    -8.4       3.29172    1777.3600
# 9           10   9.424   4.571990    -3.6       3.22357    1488.0200
# 10          11 -14.536  16.552000    -1.2       3.37056     812.9000
# 11          12 -38.496 -76.892000   -20.4       3.13145     716.4540
# 12          13  -9.744   9.363990   -10.8       3.35886     688.8980
# 13          14  -2.556 -31.368000    51.6       3.23753     661.3420
# 14          15  -9.744  47.700000    18.0       3.38766     661.3420
# 15          16 -19.328 -45.744000   -42.0       3.22521     578.6740
# 16          17 -40.892 -45.744000    10.8       3.40823     551.1180
# 17          18 -24.120  38.116000   -18.0       3.29104     537.3400
# 18          19  33.384  57.284000    20.4       3.16278     509.7840
# 19          20 -21.724  16.552000    44.4       3.22545     468.4510
# 20          21  21.404 -98.456000   -10.8       3.09844     372.0050
# 21          22  14.216  59.680000    32.4       3.15037     344.4490
# 22          23 -36.100  -9.804000     1.2       3.18530     303.1150
# 23          24   2.236 -76.892000   -25.2       3.16313     248.0030
# 24          25  45.364  50.096000    13.2       3.19382     234.2250
# 25          26   7.028 -43.348000    49.2       3.11452     220.4470
# 26          27  -4.952   9.363990    49.2       3.20634     192.8910
# 27          28 -24.120 -21.784000   -32.4       3.19598     192.8910
# 28          29 -48.080 -45.744000    34.8       3.14104     179.1130
# 29          30  11.820  30.928000    25.2       3.31071     151.5580
# 30          31 -45.684 -28.972000    30.0       3.11855     137.7800
# 31          32   4.632 -62.516000    63.6       3.07332     137.7800
# 32          33 -24.120 -38.556000   -49.2       3.18100     137.7800
# 33          34  33.384   9.363990    51.6       3.17527     137.7800
# 34          35 -69.644 -24.180000    27.6       3.12262     124.0020
# 35          36 -33.704   4.571990    63.6       3.13085     124.0020
# 36          37  -4.952  42.908000    -1.2       3.17383     124.0020
# 37          38   4.632  23.740000     3.6       3.07868     110.2240
# 38          39 -24.120 -21.784000    54.0       3.14100      96.4457
# 39          40  57.344 -40.952000   -15.6       3.12100      96.4457
# 40          41  26.196 -55.328000    42.0       3.14484      82.6677
# 41          42  33.384 -16.992000     1.2       3.13486      82.6677
#
#                                                   aal  \
# 0   12.07% Occipital_Mid_L; 11.01% no_label; 9.53%...
# 1   43.94% Frontal_Inf_Tri_L; 28.63% no_label; 25....
# 2   59.83% Cerebelum_Crus2_R; 28.36% Cerebelum_Cru...
# 3   51.63% no_label; 14.24% Caudate_R; 14.24% Caud...
# 4   38.23% Frontal_Med_Orb_L; 21.84% Frontal_Med_O...
# 5   76.39% Cerebelum_Crus2_L; 14.35% no_label; 6.9...
# 6                81.20% Precentral_L; 18.80% no_label
# 7      71.97% Frontal_Mid_2_L; 24.24% Frontal_Sup_2_L
# 8   49.61% Temporal_Pole_Sup_R; 15.50% OFCpost_R; ...
# 9   50.00% no_label; 29.63% Olfactory_R; 8.33% Cau...
# 10  38.98% Caudate_L; 37.29% Putamen_L; 16.95% no_...
# 11  48.08% Cerebelum_Crus1_L; 46.15% Fusiform_L; 5...
# 12  38.00% Caudate_L; 24.00% Olfactory_L; 20.00% n...
# 13  66.67% Paracentral_Lobule_L; 31.25% Cingulate_...
# 14  64.58% Frontal_Sup_Medial_L; 35.42% Cingulate_...
# 15              80.95% Cerebelum_9_L; 16.67% no_label
# 16  67.50% no_label; 22.50% Temporal_Mid_L; 10.00%...
# 17  76.92% OFCant_L; 10.26% OFCmed_L; 7.69% OFCpos...
# 18     70.27% Frontal_Sup_2_R; 29.73% Frontal_Mid_2_R
# 19  41.18% Frontal_Sup_2_L; 32.35% no_label; 26.47...
# 20  66.67% Lingual_R; 14.81% Occipital_Inf_R; 11.1...
# 21  52.00% Frontal_Sup_Medial_R; 44.00% Frontal_Su...
# 22  36.36% Insula_L; 36.36% no_label; 27.27% Putam...
# 23  72.22% Vermis_7; 11.11% Cerebelum_Crus2_R; 11....
# 24                            100.00% Frontal_Mid_2_R
# 25          93.75% Precuneus_R; 6.25% Cingulate_Mid_R
# 26                          100.00% Supp_Motor_Area_L
# 27  64.29% no_label; 14.29% Cerebelum_4_5_L; 14.29...
# 28  61.54% SupraMarginal_L; 30.77% Parietal_Inf_L;...
# 29             90.91% Cingulate_Ant_R; 9.09% no_label
# 30                                   100.00% no_label
# 31                                100.00% Precuneus_R
# 32         60.00% Cerebelum_8_L; 40.00% Cerebelum_9_L
# 33                            100.00% Frontal_Mid_2_R
# 34            55.56% SupraMarginal_L; 44.44% no_label
# 35  66.67% Frontal_Mid_2_L; 22.22% no_label; 11.11...
# 36                            100.00% Cingulate_Ant_L
# 37                  62.50% Caudate_R; 37.50% no_label
# 38               57.14% no_label; 42.86% Precentral_L
# 39                             100.00% Temporal_Inf_R
# 40                  50.00% Angular_R; 50.00% no_label
# 41                  66.67% Putamen_R; 33.33% no_label
#
#                                      desikan_killiany  \
# 0   24.86% Unknown; 16.63% Left-Cerebral-White-Mat...
# 1   45.73% Left-Cerebral-White-Matter; 23.86% Unkn...
# 2   77.02% Right-Cerebellum-Cortex; 12.42% Right-C...
# 3   25.52% Left-Cerebral-White-Matter; 14.54% Righ...
# 4   27.99% Left-Cerebral-White-Matter; 25.60% Unkn...
# 5   93.06% Left-Cerebellum-Cortex; 6.02% Left-Cere...
# 6   37.59% Left-Cerebral-White-Matter; 28.57% ctx-...
# 7   50.00% Unknown; 45.45% ctx-lh-rostralmiddlefro...
# 8   62.79% Unknown; 16.28% ctx-rh-superiortemporal...
# 9   34.26% ctx-rh-unknown; 25.00% Unknown; 12.96% ...
# 10  59.32% Left-Caudate; 32.20% Left-Cerebral-Whit...
# 11  50.00% Unknown; 36.54% ctx-lh-fusiform; 9.62% ...
# 12  32.00% Left-Accumbens-area; 26.00% ctx-lh-medi...
# 13          54.17% Unknown; 43.75% ctx-lh-paracentral
# 14  58.33% ctx-lh-superiorfrontal; 25.00% Left-Cer...
# 15  45.24% Left-Cerebellum-White-Matter; 35.71% Le...
# 16  87.50% Left-Cerebral-White-Matter; 7.50% ctx-l...
# 17  58.97% Unknown; 41.03% ctx-lh-lateralorbitofro...
# 18  64.86% Unknown; 32.43% ctx-rh-rostralmiddlefro...
# 19  44.12% Left-Cerebral-White-Matter; 23.53% Unkn...
# 20  66.67% Right-Cerebral-White-Matter; 25.93% ctx...
# 21      60.00% ctx-rh-superiorfrontal; 32.00% Unknown
# 22          63.64% ctx-lh-insula; 36.36% Left-Putamen
# 23  55.56% Unknown; 38.89% Right-Cerebellum-Cortex...
# 24  58.82% ctx-rh-rostralmiddlefrontal; 35.29% Unk...
# 25  62.50% ctx-rh-precuneus; 31.25% Right-Cerebral...
# 26  64.29% ctx-lh-superiorfrontal; 28.57% Unknown;...
# 27      78.57% Unknown; 21.43% ctx-lh-parahippocampal
# 28  92.31% Left-Cerebral-White-Matter; 7.69% ctx-l...
# 29  45.45% Unknown; 27.27% ctx-rh-superiorfrontal;...
# 30                 100.00% Left-Cerebral-White-Matter
# 31            60.00% Unknown; 40.00% ctx-rh-precuneus
# 32                     100.00% Left-Cerebellum-Cortex
# 33                100.00% Right-Cerebral-White-Matter
# 34        55.56% Unknown; 44.44% ctx-lh-supramarginal
# 35  77.78% ctx-lh-caudalmiddlefrontal; 22.22% Unknown
# 36  44.44% ctx-lh-rostralanteriorcingulate; 44.44%...
# 37  37.50% Right-Cerebral-White-Matter; 25.00% Rig...
# 38  71.43% Left-Cerebral-White-Matter; 28.57% ctx-...
# 39  57.14% Right-Cerebral-White-Matter; 14.29% ctx...
# 40                100.00% Right-Cerebral-White-Matter
# 41  66.67% Right-Putamen; 16.67% ctx-rh-insula; 16...
#
#                                        harvard_oxford
# 0   15.03% Left_Lateral_Occipital_Cortex_superior_...
# 1   57.26% Left_Middle_Frontal_Gyrus; 15.90% Left_...
# 2   84.68% no_label; 10.14% Right_Lateral_Occipita...
# 3   24.04% Left_Thalamus; 18.69% Right_Thalamus; 1...
# 4   46.42% Left_Frontal_Pole; 26.28% Right_Frontal...
# 5                                     99.54% no_label
# 6   57.14% Left_Precentral_Gyrus; 41.35% Left_Midd...
# 7                           100.00% Left_Frontal_Pole
# 8   55.81% Right_Temporal_Pole; 21.71% Right_Front...
# 9   27.78% Right_Subcallosal_Cortex; 20.37% Right_...
# 10           72.88% Left_Caudate; 22.03% Left_Putamen
# 11  80.77% Left_Occipital_Fusiform_Gyrus; 19.23% L...
# 12  60.00% Left_Accumbens; 38.00% Left_Subcallosal...
# 13                       93.75% Left_Precentral_Gyrus
# 14                    95.83% Left_Paracingulate_Gyrus
# 15                 54.76% no_label; 45.24% Brain-Stem
# 16  37.50% Left_Supramarginal_Gyrus_posterior_divi...
# 17  79.49% Left_Frontal_Pole; 20.51% Left_Frontal_...
# 18                         100.00% Right_Frontal_Pole
# 19  73.53% Left_Superior_Frontal_Gyrus; 20.59% Lef...
# 20  81.48% Right_Occipital_Pole; 14.81% Right_Occi...
# 21                         100.00% Right_Frontal_Pole
# 22    68.18% Left_Insular_Cortex; 31.82% Left_Putamen
# 23  66.67% no_label; 22.22% Right_Occipital_Fusifo...
# 24                         100.00% Right_Frontal_Pole
# 25                    100.00% Right_Precuneous_Cortex
# 26  64.29% Left_Paracingulate_Gyrus; 35.71% Left_J...
# 27  35.71% Left_Parahippocampal_Gyrus_posterior_di...
# 28  92.31% Left_Supramarginal_Gyrus_posterior_divi...
# 29  54.55% Right_Paracingulate_Gyrus; 45.45% Right...
# 30  60.00% Left_Supramarginal_Gyrus_anterior_divis...
# 31                    100.00% Right_Precuneous_Cortex
# 32                                   100.00% no_label
# 33                 100.00% Right_Middle_Frontal_Gyrus
# 34  77.78% Left_Supramarginal_Gyrus_anterior_divis...
# 35                  100.00% Left_Middle_Frontal_Gyrus
# 36  77.78% Left_Paracingulate_Gyrus; 22.22% Left_C...
# 37  87.50% Right_Lateral_Ventricle; 12.50% Right_C...
# 38                      100.00% Left_Precentral_Gyrus
# 39  100.00% Right_Inferior_Temporal_Gyrus_temporoo...
# 40  83.33% Right_Lateral_Occipital_Cortex_superior...
# 41  66.67% Right_Putamen; 33.33% Right_Insular_Cortex

# %% [markdown]
# ## Model 2: Task regressors for the three age groups
#
# Randomise cluster corrected p values for F-test checking for difference in means across the three groups
#
# - We find an age group difference surviving whole brain correction in response to "bad" machines (i.e. those with high variance and negative expected value)
# - No other task related regressor shows differences between groups that relates to the behavioral group differences and survives correction.

# %%
all_paths = glob.glob('/oak/stanford/groups/russpold/data/ds000054/0.0.4/derivatives/nistats/level_3/model2/*/*fstat*')
f_corrected_p_paths = [x for x in all_paths if 'corrp' in x and 'cluster' in x and 'neg' not in x]
f_corrected_p_paths = sorted(f_corrected_p_paths, key=get_index)
del all_paths

#for i in range(0, len(f_corrected_p_paths)):
#    fig = plotting.plot_stat_map(f_corrected_p_paths[i], colorbar=False, title=os.path.basename(f_corrected_p_paths[i]), threshold=0.95, draw_cross=False)
#    fig.add_overlay(f_corrected_p_paths[i], threshold=0.95, cmap=plotting.cm.black_red, colorbar=True)
i = 0
fig = plotting.plot_stat_map(f_corrected_p_paths[i], colorbar=False, title=os.path.basename(f_corrected_p_paths[i]), threshold=0.95, draw_cross=False)
fig.add_overlay(f_corrected_p_paths[i], threshold=0.95, cmap=plotting.cm.black_red, colorbar=True)

# %% [markdown]
# To understand the directionationality of the age group difference following the presentation of "bad" machines we overlay uncorrected t-statistic maps for each age group denoting the group difference cluster in yellow.

# %%
in_path = "/oak/stanford/groups/russpold/data/ds000054/0.0.4/derivatives/nistats/level_3/model2"
reg = "m1"
f_corrected_p_path = os.path.join(in_path, reg, "rand_model2_m1_cluster_corrp_fstat1.nii.gz")
kid_t_map = os.path.join(in_path, reg, "rand_model2_m1_tstat1_cluster.nii.gz")
teen_t_map = os.path.join(in_path, reg, "rand_model2_m1_tstat2_cluster.nii.gz")
adult_t_map = os.path.join(in_path, reg, "rand_model2_m1_tstat3_cluster.nii.gz")

fig = plotting.plot_stat_map(f_corrected_p_path, colorbar=False, title=os.path.basename(f_corrected_p_path), threshold=0.95, draw_cross=False)
fig.add_contours(f_corrected_p_path, levels=[0.95], colors='yellow')
fig.add_overlay(kid_t_map, threshold=3, cmap=plotting.cm.red_transparent_full_alpha_range, colorbar=False)
fig.add_overlay(teen_t_map, threshold=3, cmap=plotting.cm.blue_transparent_full_alpha_range, colorbar=False)
fig.add_overlay(adult_t_map, threshold=3, cmap=plotting.cm.green_transparent_full_alpha_range, colorbar=False)

# %% [markdown]
# The z-values at the peak voxel of the age group difference suggests that **the relationship between BOLD and the presentation of the 'bad' machine increases with age in the insula**

# %%
mni = [-43, -4, 14]
T = nib.load(kid_t_map).affine
kid_t = np.round(nib.load(kid_t_map).get_fdata()[mni2vox(mni, T)],2)
T = nib.load(teen_t_map).affine
teen_t = np.round(nib.load(teen_t_map).get_fdata()[mni2vox(mni, T)],2)
T = nib.load(adult_t_map).affine
adult_t = np.round(nib.load(adult_t_map).get_fdata()[mni2vox(mni, T)],2)

print("Z-values following the presentation of 'bad' machines at the peak voxel of age group differences are:")
print("For kids: %s"%(str(kid_t)))
print("For teens: %s"%(str(teen_t)))
print("For adults: %s"%(str(adult_t)))
# Out:
# Z-values following the presentation of 'bad' machines at the peak voxel of age group differences are:
# For kids: 7.97
# For teens: 9.94
# For adults: 11.53

# %%
#m1_level1_paths = glob.glob("/oak/stanford/groups/russpold/data/ds000054/0.0.4/derivatives/nistats/level_1/*/contrasts/sub-*_run-*_m1.nii.gz")
#m1_level1_paths = glob.glob("/oak/stanford/groups/russpold/data/ds000054/0.0.4/derivatives/nistats/level_2/*/contrasts/sub-*_m1.nii.gz")
m1_betas_paths = glob.glob("/oak/stanford/groups/russpold/data/ds000054/0.0.4/derivatives/rpe_cors/exp_exp/*/contrasts/sub-*_run-*_m1_betas.nii.gz")

all_betas = pd.DataFrame()
mni = [-43, -4, 14]
for cur_l1 in m1_betas_paths:
    cur_img = nib.load(cur_l1)
    T = cur_img.affine
    b_val = np.round(cur_img.get_fdata()[mni2vox(mni, T)],2)
    sub_num = re.findall('\d+', os.path.basename(cur_l1))[0] 
    run_num = re.findall('\d+', os.path.basename(cur_l1))[1] 
    cur_beta = pd.DataFrame(data = {"beta": [b_val],
                             "sub_num": [sub_num],
                             "run_num":[run_num]})
    all_betas = all_betas.append(cur_beta, ignore_index= True)
all_betas = all_betas.astype({"sub_num": float}) 
all_betas['age_group'] = np.where(all_betas.sub_num < 200000, "kid", np.where((all_betas.sub_num > 200000) & (all_betas.sub_num < 400000), "teen", "adult"))
#all_betas.to_csv("/oak/stanford/groups/russpold/data/ds000054/0.0.4/derivatives/nistats/level_3/model2/m1/left_insula_betas.csv")

# %% [markdown]
# Average parameter estimates across subjects for each group at the peak coordinate of the group difference

# %%
all_betas = all_betas.query("beta < 5 and beta > -5")
plot_df = all_betas.groupby(['age_group'], as_index=False).agg(
                      {'beta':['mean','sem']})
plot_df.columns = ["age_group", "mean", "sem"]
age_groups = ['kid', 'teen', 'adult']
mapping = {group: i for i, group in enumerate(age_groups)}
key = plot_df['age_group'].map(mapping)
plot_df=plot_df.iloc[key.argsort()]
plt.rcdefaults()
fig, ax = plt.subplots()
ax.bar(plot_df.age_group, plot_df["mean"], yerr=plot_df["sem"], align='center', color=[ "#E69F00","#56B4E9","#009E73"])
# Out:
# <BarContainer object of 3 artists>

# %% [markdown]
# The age groups are not very large so tests of group differences are not very well-powered. To make sure we're not missing anything potentially interesting we check whether there other possibly interesting differences that don't survive whole-brain correction. The
#
# - Not for HPE
# - Not for LPE
# - Not for PE
# - Activity for positive EV machines compared to negative EV machines increases with age in the vStr. But this is underpowered to show up with 3 groups. Since the behavioral analyses focus on the two learner groups as well in the remainder of the analyses we compare learners to non-learners.
# - (Not shown) Activity for large compared to small variance increases with age in the visual cortex

# %%
all_paths = glob.glob('%s/derivatives/nistats/level_3/model2/*/*fstat*'%(data_loc))
f_paths = [x for x in all_paths if 'ev_sen' in x if 'corrp' not in x and 'cluster' in x and 'neg' not in x and 'png' not in x and 'csv' not in x]
f_paths = sorted(f_paths, key=get_index)
#f_paths = f_paths[-5:]
del all_paths

for i in range(0, len(f_paths)):
    fig = plotting.plot_stat_map(f_paths[i], colorbar=True, title="ANOVA comparing 3 groups for pEV>nEV", threshold=10, draw_cross=False)

# %%
kids_ev_sen = '%s/derivatives/nistats/level_3/model2/ev_sen/rand_model2_ev_sen_tstat1_cluster.nii.gz'%(data_loc)
plotting.plot_stat_map(kids_ev_sen, colorbar=True, title="Kids", threshold=3, draw_cross=False, display_mode="y", cut_coords = 1)
teens_ev_sen = '%s/derivatives/nistats/level_3/model2/ev_sen/rand_model2_ev_sen_tstat2_cluster.nii.gz'%(data_loc)
plotting.plot_stat_map(teens_ev_sen, colorbar=True, title="Teens", threshold=3, draw_cross=False, display_mode="y", cut_coords = 1)
adults_ev_sen = '%s/derivatives/nistats/level_3/model2/ev_sen/rand_model2_ev_sen_tstat3_cluster.nii.gz'%(data_loc)
plotting.plot_stat_map(adults_ev_sen, colorbar=True, title="Adults", threshold=3, draw_cross=False, display_mode="y", cut_coords = 1)

# %%
#create_output(f_paths[0], cluster_extent=5, voxel_thresh = 10)

# %% [markdown]
# Clusters where pEV>nEV differs between groups

# %%
ev_sen_clusters = pd.read_csv('%s/rand_model2_ev_sen_fstat1_cluster_clusters.csv'%(os.path.dirname(f_paths[0])))
ev_sen_clusters
# Out:
#     cluster_id  peak_x    peak_y  peak_z  cluster_mean  volume_mm  \
# 0            1 -14.536  16.55200    -6.0       13.5629  2245.8100
# 1            2  33.384 -86.47600    -1.2       11.9436  2135.5800
# 2            3 -50.476 -74.49600    -3.6       11.3605  2108.0300
# 3            4 -38.496 -91.26800     8.4       12.2283  1887.5800
# 4            5  11.820  14.15600    -8.4       12.8035  1873.8000
# 5            6  35.780 -50.53600   -20.4       11.1421   716.4540
# 6            7  28.592 -67.30800    34.8       11.6281   496.0060
# 7            8  42.968   6.96799    30.0       11.4924   468.4510
# 8            9  11.820 -12.20000     8.4       12.1517   413.3390
# 9           10 -21.724 -74.49600    -8.4       11.0388   248.0030
# 10          11  -9.744 -93.66400    20.4       10.8528   179.1130
# 11          12 -26.516 -55.32800    51.6       10.6704   124.0020
# 12          13  11.820 -74.49600    42.0       10.3172    82.6677
#
#                                                   aal  \
# 0                  70.55% Caudate_L; 20.25% Putamen_L
# 1      60.65% Occipital_Inf_R; 37.42% Occipital_Mid_R
# 2   52.94% Occipital_Inf_L; 27.45% Occipital_Mid_L...
# 3             74.45% Occipital_Mid_L; 21.90% no_label
# 4   61.76% Caudate_R; 13.97% no_label; 10.29% Puta...
# 5   51.92% Fusiform_R; 32.69% Temporal_Inf_R; 15.3...
# 6      69.44% Occipital_Mid_R; 30.56% Occipital_Sup_R
# 7      58.82% Precentral_R; 41.18% Frontal_Inf_Oper_R
# 8                                  100.00% Thalamus_R
# 9                 83.33% Lingual_L; 16.67% Fusiform_L
# 10            69.23% Occipital_Sup_L; 30.77% Cuneus_L
# 11       66.67% Parietal_Sup_L; 33.33% Parietal_Inf_L
# 12                66.67% Cuneus_R; 33.33% Precuneus_R
#
#                                      desikan_killiany  \
# 0   40.49% Left-Caudate; 26.38% Left-Accumbens-are...
# 1   49.68% ctx-rh-lateraloccipital; 47.10% Right-C...
# 2   41.83% ctx-lh-lateraloccipital; 21.57% Left-Ce...
# 3   51.09% ctx-lh-lateraloccipital; 27.01% Unknown...
# 4   34.56% Right-Accumbens-area; 33.82% Right-Caud...
# 5   53.85% ctx-rh-fusiform; 26.92% Right-Cerebral-...
# 6   41.67% Unknown; 30.56% Right-Cerebral-White-Ma...
# 7   47.06% Unknown; 38.24% ctx-rh-precentral; 8.82...
# 8                       100.00% Right-Thalamus-Proper
# 9       61.11% ctx-lh-lingual; 38.89% ctx-lh-fusiform
# 10  76.92% Left-Cerebral-White-Matter; 23.08% ctx-...
# 11  55.56% Left-Cerebral-White-Matter; 44.44% ctx-...
# 12  66.67% ctx-rh-precuneus; 16.67% Right-Cerebral...
#
#                                        harvard_oxford
# 0   38.04% Left_Caudate; 34.97% Left_Accumbens; 14...
# 1   76.77% Right_Lateral_Occipital_Cortex_inferior...
# 2   96.73% Left_Lateral_Occipital_Cortex_inferior_...
# 3   61.31% Left_Occipital_Pole; 27.01% Left_Latera...
# 4   44.12% Right_Accumbens; 25.00% Right_Caudate; ...
# 5   92.31% Right_Temporal_Occipital_Fusiform_Corte...
# 6   100.00% Right_Lateral_Occipital_Cortex_superio...
# 7   85.29% Right_Precentral_Gyrus; 14.71% Right_Mi...
# 8                              100.00% Right_Thalamus
# 9   94.44% Left_Occipital_Fusiform_Gyrus; 5.56% Le...
# 10                        100.00% Left_Occipital_Pole
# 11              100.00% Left_Superior_Parietal_Lobule
# 12  83.33% Right_Precuneous_Cortex; 16.67% Right_L...

# %% [markdown]
# ## Model 3: Task regressors for learners vs. non-learners

# %% [markdown]
# Because the three age groups are not large enough to powerfully compare task-related regressor across groups and because behaviorally there is heteregoneity within the age groups with respect to task-performance we focus the rest of the imaging analyses on two groups based on task performance: Learners and non-learners.
#
# Learners are defined as those who are more likely to make correct choices later in the task based on a logistic regression of their correct responses over trial number.
#
# Cluster corrected p-value maps for the t-test checking regions where relationship between task regressor and BOLD activity is stronger for learners compared to non-learners.
#
# - Learners have larger activity in both but more so in the right frontal pole/middle frontal gyrus/inferiori frontal gyrus for positive EV machines compared to negative EV machines.
# - No other task-related regressor comparison between the learner groups survives whole-brain correction

# %%
all_paths = glob.glob('%s/derivatives/nistats/level_3/model3/*/*tstat1*'%(data_loc))
pos_t_corrected_p_paths = [x for x in all_paths if 'ev_sen' in x if 'corrp' in x and 'cluster' in x and 'neg' not in x]
neg_t_corrected_p_paths = [x for x in all_paths if 'ev_sen' in x if 'corrp' in x and 'cluster' in x and 'neg' in x]
neg_t_corrected_p_paths = sorted(neg_t_corrected_p_paths, key=get_index)
pos_t_corrected_p_paths = sorted(pos_t_corrected_p_paths, key=get_index)
del all_paths

for i in range(0, len(pos_t_corrected_p_paths)):
    fig = plotting.plot_stat_map(pos_t_corrected_p_paths[i], colorbar=False, title="Learner > Non-learner for pEV > nEV (corrected)", threshold=0.95, draw_cross=False)
    fig.add_overlay(pos_t_corrected_p_paths[i], threshold=0.95, cmap=plotting.cm.black_red, colorbar=True)
    fig.add_overlay(neg_t_corrected_p_paths[i], threshold=0.95, cmap=plotting.cm.black_blue, colorbar=False)

# %%
all_paths = glob.glob('%s/derivatives/nistats/level_3/model3/*/*tstat1*'%(data_loc))
t_paths = [x for x in all_paths if 'ev_sen' in x if 'corrp' not in x and 'cluster' in x and 'neg' not in x]
#t_paths = [x for x in all_paths if 'corrp' not in x and 'cluster' in x and 'neg' not in x]
t_paths = sorted(t_paths, key=get_index)
del all_paths

for i in range(0, len(t_paths)):
    fig = plotting.plot_stat_map(t_paths[i], colorbar=True, title="Learner > Non-learner for pEV > nEV (uncorrected)", threshold=3, draw_cross=False, cut_coords = [-11, 15, -4])
    #fig = plotting.plot_stat_map(t_paths[i], colorbar=True, title=os.path.basename(t_paths[i]), threshold=3, draw_cross=False, cut_coords = [-11, 15, -4])

# %% [markdown]
# ## Model 4: Change in task regressors for learners vs. non-learners
#
# Interactive model checking effect of first vs. second half of task, learner vs. non-learner and the interaction of these two factors
#
# ### Main effect of first vs. second half
#
# **None of the task-related regressor show change in activity between the two halves that survives whole-brain correction.**
#
# Hints of potentially interesting effects in uncorrected maps suggest:
# - M1 activity is higher in the first half compared to the the second half in the caudate and frontal pole
# - HPE activity is higher in the second half in ACC and vmPFC
# - LPE activity is higher in the first half in the frontal pole
# - EV sensitivity (i.e. pEV>nEV) is higher in the first half in the thalamus
# - Var sensitivity (i.e. hVAR>lVAR) is higher in the first half in the middle frontal gyrus
#     - Possible interpretation: *With learning value-related regions no longer respond to the "bad" machine, and conflict/higher-order learning regions respond stronger to better than expected outcomes in more variable conditions*

# %%
m1_path = '%s/derivatives/nistats/level_3/model4/m1/rand_model4_m1_tstat1_cluster.nii.gz'%(data_loc)
plotting.plot_stat_map(m1_path, colorbar=True, title="M1 - First half>second half", threshold=3, draw_cross=False)

hpe_path = '%s/derivatives/nistats/level_3/model4/hpe/rand_model4_hpe_tstat1_cluster.nii.gz'%(data_loc)
plotting.plot_stat_map(hpe_path, colorbar=True, title="HPE - First half>second half", threshold=3, draw_cross=False, cut_coords = [-5,20,23])

lpe_path = '%s/derivatives/nistats/level_3/model4/lpe/rand_model4_lpe_tstat1_cluster.nii.gz'%(data_loc)
plotting.plot_stat_map(lpe_path, colorbar=True, title="LPE - First half>second half", threshold=3, draw_cross=False)

ev_sen_path = '%s/derivatives/nistats/level_3/model4/ev_sen/rand_model4_ev_sen_tstat1_cluster.nii.gz'%(data_loc)
plotting.plot_stat_map(ev_sen_path, colorbar=True, title="EV_sen - First half>second half", threshold=3, draw_cross=False)

var_sen_path = '%s/derivatives/nistats/level_3/model4/var_sen/rand_model4_var_sen_tstat1_cluster.nii.gz'%(data_loc)
plotting.plot_stat_map(var_sen_path, colorbar=True, title="VAR_sen - First half>second half", threshold=3, draw_cross=False)

# %% [markdown]
# ### Main effect of learner vs. non-learner
#
# When looking at differences between learners and non-learners we found that learners responded more strongly to pEV machines compared to nEV machines. We find this when accounting for the effect of halves as well and no other task-related differences between the two groups that appear after accounting for the effect of halves.

# %% [markdown]
# ### Interaction of first vs. second half with learner vs. non-learner
#
# No interaction between half and learner groups survives whole brain correction.

# %% [markdown]
# ## ROI analysis of the vStr for learners vs. non-learners
#
# In [Schoenberg et al. (2007)](https://www.jneurosci.org/content/jneuro/27/47/12860.full.pdf) they do an ROI analysis of learners vs. non-learners comparing average parameter estimates for PE regressor from dorsal striatum (though based on [Table 3S](https://www-jneurosci-org.stanford.idm.oclc.org/content/jneuro/suppl/2007/11/21/27.47.12860.DC1/Supplemental_JN-RM-2496-07.R2.pdf) in their supplements they seem to refer to z-scores as 'parameter estimates').
#
# Inspired by this here we compare the average beta/z-score for learners vs. non-learners from several ROIs.
#
# See details of this analysis [in a separate notebook](https://zenkavi.github.io/DevStudy_Analyses/output/reports/Roi_analyses.nb.html)

# %% [markdown]
# ## Functional connectivity differences for learners vs. non-learners
#
# ### vStr-vmPFC

# %% [markdown]
# ### Insula - vMPFC

# %% [markdown]
# Remember to check out https://github.com/nilearn/nilearn/issues/1464 for ideas on components of nilearn plots
